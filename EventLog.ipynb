# %%
import pandas as pd

sf = pd.read_csv("out.csv")

# %%
entrypoints = sf["ENTRY_POINT"].unique()

# %%
sf["RUN_TIME"].describe()
# Out:
# count    7.343100e+04
# mean     1.006228e+03
# std      1.724655e+04
# min      1.300000e+01
# 25%      1.800000e+01
# 50%      3.200000e+01
# 75%      1.650000e+02
# max      1.782798e+06
# Name: RUN_TIME, dtype: float64

# %%
sf["RUN_TIME"]
# Out:
# 0         2723
# 1        42082
# 2           81
# 3         2301
# 4        13672
# 5           34
# 6           34
# 7           66
# 8           34
# 9           35
# 10          52
# 11          63
# 12          38
# 13          45
# 14          32
# 15          36
# 16          57
# 17          33
# 18          63
# 19          31
# 20          91
# 21        3565
# 22       46054
# 23          69
# 24        3386
# 25       17643
# 26          70
# 27          62
# 28          44
# 29          42
#          ...
# 73401    22675
# 73402    24848
# 73403    18282
# 73404    18613
# 73405    18900
# 73406    17412
# 73407    19041
# 73408    20200
# 73409    21627
# 73410    21127
# 73411    19645
# 73412    19610
# 73413    20158
# 73414    20699
# 73415    20141
# 73416    19255
# 73417    21358
# 73418    25823
# 73419    21100
# 73420    20499
# 73421    23807
# 73422    20399
# 73423    22342
# 73424    23060
# 73425    20316
# 73426    13747
# 73427    54839
# ...
